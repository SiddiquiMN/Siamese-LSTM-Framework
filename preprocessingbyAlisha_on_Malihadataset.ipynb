# %%
import os
import cv2
import numpy as np
import concurrent.futures
import shutil

input_folder = "/content/drive/MyDrive/Maliha Dataset"
output_folder = "/content/drive/MyDrive/PreprocessedMalihaDataset"

if os.path.exists(output_folder):
    # Remove the contents of the output folder
    shutil.rmtree(output_folder)
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

def process_image(image_path):
    image = cv2.imread(image_path)

    # Convert the image to HSV color space
    hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    # Increase the saturation by a factor (e.g., 1.5 for 50% increase)
    saturation_factor = 1.5
    hsv_image[:,:,1] = np.clip(hsv_image[:,:,1] * saturation_factor, 0, 255).astype(np.uint8)

    # Define the lower and upper bounds for green in the HSV color space
    lower_green = np.array([40, 40, 40])
    upper_green = np.array([80, 255, 255])

    # Create a green mask
    green_mask = cv2.inRange(hsv_image, lower_green, upper_green)

    # Apply the green mask to the original image
    green_highlighted_image = cv2.bitwise_and(image, image, mask=green_mask)

    output_path = os.path.join(output_folder, f"green_highlighted_{os.path.basename(image_path)}")
    cv2.imwrite(output_path, green_highlighted_image)
    print(f"Processed: {os.path.basename(image_path)}")

image_paths = [os.path.join(input_folder, filename) for filename in os.listdir(input_folder) if filename.endswith(".jpg")]

# Batch size for processing
batch_size = 50

# Process images in parallel using multiple threads
with concurrent.futures.ThreadPoolExecutor() as executor:
    executor.map(process_image, image_paths)

print("Processing complete.")
# Out:
# Processed: granville island 2000.jpg
# Processed: granville island 2005.jpg
# Processed: granville island 2010.jpg
# Processed: granville island 2015.jpg
# Processed: granville island 2020.jpg
# Processed: Shaugnessy Park, Vancouver 2020.jpg
# Processed: Shaugnessy Park, Vancouver 2015.jpg
# Processed: Shaugnessy Park, Vancouver 2005.jpg
# Processed: Shaugnessy Park, Vancouver 2000.jpg
# Processed: Shaugnessy Park, Vancouver 2010.jpg
# Processed: vanier park 2020.jpg
# Processed: vanier park 2015.jpg
# Processed: vanier park 2010.jpg
# Processed: vanier park 2005.jpg
# Processed: vanier park 2000.jpg
# Processed: granville park 2020.jpg
# Processed: granville park 2005.jpg
# Processed: granville park 2015.jpg
# Processed: granville park 2010.jpg
# Processed: granville park 2000.jpg
# Processed: banff park 2020.jpg
# Processed: banff park 2015.jpg
# Processed: banff park 2010.jpg
# Processed: banff park 2000.jpg
# Processed: banff 2000.jpg
# Processed: banff 2010.jpg
# Processed: banff 2020.jpg
# Processed: banff 2015.jpg
# Processed: banff 2005.jpg
# Processed: quarry lake park 2015.jpg
# Processed: quarry lake park 2020.jpg
# Processed: quarry lake park 2010.jpg
# Processed: quarry lake park 2005.jpg
# Processed: quarry lake park 2000.jpg
# Processed: Calgary zoo 2020.jpg
# Processed: Calgary zoo 2015.jpg
# Processed: Calgary zoo 2000.jpg
# Processed: Calgary zoo 2005.jpg
# Processed: Calgary zoo 2010.jpg
# Processed: Pierce state park 2000.jpg
# Processed: Pierce state park 2020.jpg
# Processed: Pierce state park 2005.jpg
# Processed: Pierce state park 2010.jpg
# Processed: Pierce state park 2015.jpg
# Processed: Fox Hollow Golf Course 2020.jpg
# Processed: Fox Hollow Golf Course 2015.jpg
# Processed: Fox Hollow Golf Course 2010.jpg
# Processed: Fox Hollow Golf Course 2005.jpg
# Processed: Fox Hollow Golf Course 2000.jpg
# Processed: MNP Sports Center Lindsay Park 2020.jpg
# Processed: MNP Sports Center Lindsay Park 2015.jpg
# Processed: MNP Sports Center Lindsay Park 2010.jpg
# Processed: MNP Sports Center Lindsay Park 2005.jpg
# Processed: MNP Sports Center Lindsay Park 2000.jpg
# Processed: Rideau Park School Roxboro Park 2000.jpg
# Processed: Rideau Park School Roxboro Park 2020.jpg
# Processed: Rideau Park School Roxboro Park 2005.jpg
# Processed: Rideau Park School Roxboro Park 2010.jpg
# Processed: Rideau Park School Roxboro Park 2015.jpg
# Processed: Tollkeeper's park 2020.jpg
# Processed: Tollkeeper's park 2015.jpg
# Processed: Tollkeeper's park 2010.jpg
# Processed: Tollkeeper's park 2005.jpg
# Processed: Tollkeeper's park 2000.jpg
# Processed: Clark Park 2015.jpg
# Processed: Clark Park 2020.jpg
# Processed: Clark Park 2010.jpg
# Processed: Clark Park 2005.jpg
# Processed: Clark Park 2000.jpg
# Processed: Dorchestor Park 2020.jpg
# Processed: Dorchestor Park 2015.jpg
# Processed: Dorchestor Park 2010.jpg
# Processed: Dorchestor Park 2005.jpg
# Processed: Dorchestor Park 2000.jpg
# Processed: Folkstone 2015.jpg
# Processed: Folkstone 2020.jpg
# Processed: Folkstone 2010.jpg
# Processed: Folkstone 2005.jpg
# Processed: Folkstone 2000.jpg
# Processed: Stillmeadow Park, ON 2020.jpg
# Processed: Stillmeadow Park, ON 2015.jpg
# Processed: Stillmeadow Park, ON 2010.jpg
# Processed: Stillmeadow Park, ON 2005.jpg
# Processed: Stillmeadow Park, ON 2000.jpg
# Processed: Chapman Valley Park 2020.jpg
# Processed: Chapman Valley Park 2015.jpg
# Processed: Chapman Valley Park 2005.jpg
# Processed: Chapman Valley Park 2010.jpg
# Processed: Chapman Valley Park 2000.jpg
# Processed: Blue Haven 2000.jpg
# Processed: Blue Haven 2005.jpg
# Processed: Blue Haven 2015.jpg
# Processed: Blue Haven 2010.jpg
# Processed: Blue Haven 2020.jpg
# Processed: Rancho Punho Brazil 2000.jpg
# Processed: Rancho Punho Brazil 2020.jpg
# Processed: Rancho Punho Brazil 2015.jpg
# Processed: Rancho Punho Brazil 2010.jpg
# Processed: Rancho Punho Brazil 2005.jpg
# Processed: Floor de Lanjeira, Brazil 2005.jpg
# Processed: Floor de Lanjeira, Brazil 2010.jpg
# Processed: Floor de Lanjeira, Brazil 2015.jpg
# Processed: Floor de Lanjeira, Brazil 2020.jpg
# Processed: Vivant Residential, Brazil 2004.jpg
# Processed: Vivant Residential, Brazil 2015.jpg
# Processed: Vivant Residential, Brazil 2010.jpg
# Processed: Vivant Residential, Brazil 2020.jpg
# Processed: Bora Bora Hills, Brazil 2008.jpg
# Processed: Bora Bora Hills, Brazil 2020.jpg
# Processed: Bora Bora Hills, Brazil 2015.jpg
# Processed: Bora Bora Hills, Brazil 2010.jpg
# Processed: Bora Bora Hills, Brazil 2000.jpg
# Processed: Casa do Taichi, Brazil 2000.jpg
# Processed: Bora Bora Hills, Brazil 2005.jpg
# Processed: Casa do Taichi, Brazil 2005.jpg
# Processed: Casa do Taichi, Brazil 2010.jpg
# Processed: Casa do Taichi, Brazil 2015.jpg
# Processed: Casa do Taichi, Brazil 2020.jpg
# Processed: R. Arquiteto Henrique Mindlin, Brazil 2000.jpg
# Processed: R. Arquiteto Henrique Mindlin, Brazil 2005.jpg
# Processed: R. Arquiteto Henrique Mindlin, Brazil 2010.jpg
# Processed: R. Arquiteto Henrique Mindlin, Brazil 2015.jpg
# Processed: R. Arquiteto Henrique Mindlin, Brazil 2020.jpg
# Processed: R. Cinco de Janeiro, Brazil 2000.jpg
# Processed: R. Cinco de Janeiro, Brazil 2005.jpg
# Processed: R. Cinco de Janeiro, Brazil 2010.jpg
# Processed: R. Cinco de Janeiro, Brazil 2015.jpg
# Processed: R. Cinco de Janeiro, Brazil 2020.jpg
# Processed: R. Itabuna da Floresta , Brazil 2015.jpg
# Processed: R. Itabuna da Floresta , Brazil 2020.jpg
# Processed: R. Itabuna da Floresta , Brazil 2010.jpg
# Processed: R. Itabuna da Floresta , Brazil 2000.jpg
# Processed: R. Itabuna da Floresta , Brazil 2005.jpg
# Processed: Alto da Boa Vista, Brazil 2000.jpg
# Processed: Alto da Boa Vista, Brazil 2005.jpg
# Processed: Alto da Boa Vista, Brazil 2010.jpg
# Processed: Alto da Boa Vista, Brazil 2020.jpg
# Processed: Alto da Boa Vista, Brazil 2015.jpg
# Processed: Cordovil, Brazil 2000.jpg
# Processed: Cordovil, Brazil 2004.jpg
# Processed: Cordovil, Brazil 2010.jpg
# Processed: Cordovil, Brazil 2015.jpg
# Processed: Cordovil, Brazil 2020.jpg
# Processing complete.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
