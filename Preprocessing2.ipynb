# %%
#vgg16
import os
import cv2
import numpy as np
import concurrent.futures
import shutil

input_folder = "/content/drive/MyDrive/Sowmik Dataset/Recheck_prediction_valid_dataset"
output_folder = "/content/drive/MyDrive/Sowmik Dataset/Recheck_prediction_valid_dataset/masks"

if os.path.exists(output_folder):
    # Remove the contents of the output folder
    shutil.rmtree(output_folder)
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

def process_image(image_path):
    image = cv2.imread(image_path)
    hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    lower_green = np.array([40, 40, 40])
    upper_green = np.array([80, 255, 255])
    green_mask = cv2.inRange(hsv_image, lower_green, upper_green)
    green_highlighted_image = cv2.bitwise_and(image, image, mask=green_mask)

    output_path = os.path.join(output_folder, f"green_highlighted_{os.path.basename(image_path)}")
    cv2.imwrite(output_path, green_highlighted_image)
    print(f"Processed: {os.path.basename(image_path)}")

image_paths = [os.path.join(input_folder, filename) for filename in os.listdir(input_folder) if filename.endswith(".jpg")]

# Batch size for processing
batch_size = 50

# Process images in parallel using multiple threads
with concurrent.futures.ThreadPoolExecutor() as executor:
    executor.map(process_image, image_paths)

print("Processing complete.")
# Out:
# Streaming output truncated to the last 5000 lines.
# Processed: 950926_sat_87.jpg
# Processed: 873132_sat_47.jpg
# Processed: 952430_sat_61.jpg
# Processed: 940229_sat_47.jpg
# Processed: 899693_sat_86.jpg
# Processed: 877160_sat_45.jpg
# Processed: 897901_sat_30.jpg
# Processed: 888343_sat_10.jpg
# Processed: 861353_sat_25.jpg
# Processed: 861353_sat_63.jpg
# Processed: 876248_sat_63.jpg
# Processed: 918446_sat_36.jpg
# Processed: 919051_sat_42.jpg
# Processed: 899693_sat_70.jpg
# Processed: 875328_sat_87.jpg
# Processed: 873132_sat_46.jpg
# Processed: 925425_sat_28.jpg
# Processed: 873132_sat_08.jpg
# Processed: 866782_sat_26.jpg
# Processed: 861353_sat_03.jpg
# Processed: 866782_sat_51.jpg
# Processed: 897901_sat_41.jpg
# Processed: 848728_sat_88.jpg
# Processed: 899693_sat_66.jpg
# Processed: 877160_sat_66.jpg
# Processed: 858771_sat_78.jpg
# Processed: 918446_sat_12.jpg
# Processed: 866782_sat_35.jpg
# Processed: 876248_sat_44.jpg
# Processed: 919051_sat_20.jpg
# ...

# %%
import cv2
from PIL import Image, ImageEnhance
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

def preprocess_image(input_path, output_path, saturation_factor=1.5, contrast_factor=1.5):
    # Load image from Google Drive
    img = cv2.imread(input_path)

    # Convert BGR to RGB
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # Convert image to PIL format
    pil_img = Image.fromarray(img)

    # Increase saturation
    enhancer = ImageEnhance.Color(pil_img)
    img_saturated = enhancer.enhance(1.5)

    # Increase contrast
    enhancer = ImageEnhance.Contrast(img_saturated)
    img_contrast = enhancer.enhance(1.5)

    # Save the preprocessed image
    img_contrast.save(output_path)

# Specify the paths
input_image_path = '/content/drive/MyDrive/Sowmik Dataset/New dataset/Park/sultanpark_2020.jpg'
output_image_path = '/content/drive/MyDrive/preprocessed_sultanpark_2020.jpg'

# Preprocess the image and save
preprocess_image(input_image_path, output_image_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import cv2
import numpy as np
import concurrent.futures


input_folder = "/content/drive/MyDrive/Sowmik Dataset/Recheck_prediction_valid_dataset"
output_folder = "/content/drive/MyDrive/Sowmik Dataset/Recheck_prediction_valid_dataset/masks"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

def process_image(image_path):
    image = cv2.imread(image_path)
    hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    lower_green = np.array([40, 40, 40])
    upper_green = np.array([80, 255, 255])
    green_mask = cv2.inRange(hsv_image, lower_green, upper_green)
    green_highlighted_image = cv2.bitwise_and(image, image, mask=green_mask)

    output_path = os.path.join(output_folder, f"green_highlighted_{os.path.basename(image_path)}")
    cv2.imwrite(output_path, green_highlighted_image)
    print(f"Processed: {os.path.basename(image_path)}")

image_paths = [os.path.join(input_folder, filename) for filename in os.listdir(input_folder) if filename.endswith(".jpg")]

# Process images in parallel using multiple processes
with concurrent.futures.ProcessPoolExecutor() as executor:
    executor.map(process_image, image_paths)

print("Processing complete.")
# Out:
# Processed: 949559_sat_82.jpg
# Processed: 866782_sat_13.jpg
# Processed: 888343_sat_06.jpg
# Processed: 888343_sat_57.jpg
# Processed: 873132_sat_87.jpg
# Processed: 906113_sat_17.jpg
# Processed: 940229_sat_44.jpg
# Processed: 850510_sat_71.jpg
# Processed: 870705_sat_11.jpg
# Processed: 940229_sat_40.jpg
# Processed: 925425_sat_20.jpg
# Processed: 897901_sat_36.jpg
# Processed: 906113_sat_16.jpg
# Processed: 858771_sat_23.jpg
# Processed: 870705_sat_12.jpg
# Processed: 861353_sat_73.jpg
# Processed: 918446_sat_24.jpg
# Processed: 897901_sat_24.jpg
# Processed: 897901_sat_06.jpg
# Processed: 918446_sat_22.jpg
# Processed: 888343_sat_16.jpg
# Processed: 950926_sat_41.jpg
# Processed: 897901_sat_31.jpg
# Processed: 877160_sat_57.jpg
# Processed: 888343_sat_84.jpg
# Processed: 850510_sat_26.jpg
# Processed: 918446_sat_13.jpg
# Processed: 877160_sat_61.jpg
# Processed: 918446_sat_27.jpg
# Processed: 850510_sat_31.jpg
# Processed: 850510_sat_13.jpg
# Processed: 943943_sat_82.jpg
# ...
