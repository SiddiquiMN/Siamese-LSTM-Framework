# %%
import os
import cv2
import numpy as np
import concurrent.futures
import shutil

input_folder = "/content/drive/MyDrive/Sowmik Dataset/New dataset/Aug_all_processed_data/aug_forest"
output_folder = "/content/drive/MyDrive/Sowmik Dataset/New dataset/Aug_all_processed_data/aug_forest/pre_img_out"
saturated_output_folder = "/content/drive/MyDrive/Sowmik Dataset/New dataset/Aug_all_processed_data/aug_forest/pre_img_sat"

if os.path.exists(output_folder):
    # Remove the contents of the output folder
    shutil.rmtree(output_folder)
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

if os.path.exists(saturated_output_folder):
    # Remove the contents of the saturated output folder
    shutil.rmtree(saturated_output_folder)
if not os.path.exists(saturated_output_folder):
    os.makedirs(saturated_output_folder)

def process_image(image_path):
    image = cv2.imread(image_path)

    # Convert the image to HSV color space
    hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    # Increase the saturation by a factor (e.g., 1.5 for 50% increase)
    saturation_factor = 1.5
    saturated_image = cv2.cvtColor(cv2.cvtColor(hsv_image, cv2.COLOR_HSV2BGR), cv2.COLOR_BGR2HSV)
    saturated_image[:,:,1] = np.clip(saturated_image[:,:,1] * saturation_factor, 0, 255).astype(np.uint8)
    saturated_image = cv2.cvtColor(saturated_image, cv2.COLOR_HSV2BGR)

    # Save the saturated image
    saturated_output_path = os.path.join(saturated_output_folder, f"saturated_{os.path.basename(image_path)}")
    cv2.imwrite(saturated_output_path, saturated_image)

    # Define the lower and upper bounds for green in the HSV color space
    lower_green = np.array([40, 40, 40])
    upper_green = np.array([80, 255, 255])

    # Create a green mask
    green_mask = cv2.inRange(hsv_image, lower_green, upper_green)

    # Apply the green mask to the original image
    green_highlighted_image = cv2.bitwise_and(image, image, mask=green_mask)

    output_path = os.path.join(output_folder, f"pp_{os.path.basename(image_path)}")
    cv2.imwrite(output_path, green_highlighted_image)
    print(f"Processed: {os.path.basename(image_path)}")

image_paths = [os.path.join(input_folder, filename) for filename in os.listdir(input_folder) if filename.endswith(".jpg")]

# Batch size for processing
batch_size = 50

# Process images in parallel using multiple threads
with concurrent.futures.ThreadPoolExecutor() as executor:
    executor.map(process_image, image_paths)

print("Processing complete.")
# Out:
# Processed: augmented_vertical_Odtuf_2015.jpg
# Processed: augmented_horizontal_Odtuf_2015.jpg
# Processed: augmented_rotate_Odtuf_2015.jpg
# Processed: augmented_horizontal_Odtuf_2020.jpg
# Processed: augmented_rotate_Odtuf_2020.jpg
# Processed: augmented_vertical_Odtuf_2020.jpg
# Processed: augmented_vertical_Odtuf_2010.jpg
# Processed: augmented_horizontal_Odtuf_2010.jpg
# Processed: augmented_rotate_Odtuf_2010.jpg
# Processed: augmented_horizontal_Odtuf_2005.jpg
# Processed: augmented_horizontal_Odtuf_2000.jpg
# Processed: augmented_vertical_Odtuf_2005.jpg
# Processed: augmented_rotate_Odtuf_2005.jpg
# Processed: augmented_vertical_Odtuf_2000.jpg
# Processed: augmented_rotate_Odtuf_2000.jpg
# Processed: augmented_horizontal_forestt_2020.jpg
# Processed: augmented_vertical_forestt_2020.jpg
# Processed: augmented_rotate_forestt_2020.jpg
# Processed: augmented_horizontal_forestt_2015.jpg
# Processed: augmented_vertical_forestt_2015.jpg
# Processed: augmented_rotate_forestt_2015.jpg
# Processed: augmented_horizontal_forestt_2010.jpg
# Processed: augmented_vertical_forestt_2010.jpg
# Processed: augmented_rotate_forestt_2010.jpg
# Processed: augmented_horizontal_forestt_2005.jpg
# Processed: augmented_vertical_forestt_2005.jpg
# Processed: augmented_rotate_forestt_2005.jpg
# Processed: augmented_horizontal_forestt_2000.jpg
# Processed: augmented_vertical_forestt_2000.jpg
# Processed: augmented_horizontal_forestv_2020.jpg
# Processed: augmented_rotate_forestt_2000.jpg
# Processed: augmented_vertical_forestv_2020.jpg
# Processed: augmented_rotate_forestv_2020.jpg
# Processed: augmented_horizontal_forestv_2015.jpg
# Processed: augmented_vertical_forestv_2015.jpg
# Processed: augmented_rotate_forestv_2015.jpg
# Processed: augmented_horizontal_forestv_2010.jpg
# Processed: augmented_vertical_forestv_2010.jpg
# Processed: augmented_rotate_forestv_2010.jpg
# Processed: augmented_vertical_forestv_2005.jpg
# Processed: augmented_horizontal_forestv_2005.jpg
# Processed: augmented_rotate_forestv_2000.jpg
# Processed: augmented_horizontal_forestv_2000.jpg
# Processed: augmented_horizontal_forestp_2020.jpg
# Processed: augmented_rotate_forestv_2005.jpg
# Processed: augmented_vertical_forestv_2000.jpg
# Processed: augmented_vertical_forestp_2020.jpg
# Processed: augmented_horizontal_forestp_2015.jpg
# Processed: augmented_rotate_forestp_2015.jpg
# Processed: augmented_rotate_forestp_2020.jpg
# Processed: augmented_vertical_forestp_2015.jpg
# Processed: augmented_horizontal_forestp_2010.jpg
# Processed: augmented_vertical_forestp_2010.jpg
# Processed: augmented_rotate_forestp_2005.jpg
# Processed: augmented_rotate_forestp_2010.jpg
# Processed: augmented_horizontal_forestp_2005.jpg
# Processed: augmented_vertical_forestp_2005.jpg
# Processed: augmented_horizontal_forestp_2000.jpg
# Processed: augmented_vertical_forestp_2000.jpg
# Processed: augmented_rotate_forestp_2000.jpg
# Processed: augmented_horizontal_yakutf_2020.jpg
# Processed: augmented_rotate_yakutf_2020.jpg
# Processed: augmented_vertical_yakutf_2020.jpg
# Processed: augmented_horizontal_yakutf_2015.jpg
# Processed: augmented_vertical_yakutf_2015.jpg
# Processed: augmented_rotate_yakutf_2015.jpg
# Processed: augmented_horizontal_yakutf_2010.jpg
# Processed: augmented_vertical_yakutf_2010.jpg
# Processed: augmented_rotate_yakutf_2010.jpg
# Processed: augmented_horizontal_yakutf_2005.jpg
# Processed: augmented_vertical_yakutf_2005.jpg
# Processed: augmented_rotate_yakutf_2005.jpg
# Processed: augmented_horizontal_yakutf_2000.jpg
# Processed: augmented_vertical_yakutf_2000.jpg
# Processed: augmented_rotate_yakutf_2000.jpg
# Processed: augmented_horizontal_shell_2020.jpg
# Processed: augmented_vertical_shell_2020.jpg
# Processed: augmented_rotate_shell_2020.jpg
# Processed: augmented_horizontal_shell_2015.jpg
# Processed: augmented_vertical_shell_2015.jpg
# Processed: augmented_rotate_shell_2015.jpg
# Processed: augmented_horizontal_shell_2010.jpg
# Processed: augmented_vertical_shell_2010.jpg
# Processed: augmented_rotate_shell_2010.jpg
# Processed: augmented_horizontal_shell_2005.jpg
# Processed: augmented_vertical_shell_2005.jpg
# Processed: augmented_rotate_shell_2005.jpg
# Processed: augmented_horizontal_shell_2000.jpg
# Processed: augmented_vertical_shell_2000.jpg
# Processed: augmented_rotate_shell_2000.jpg
# Processed: augmented_horizontal_elvacenzy_2020.jpg
# Processed: augmented_vertical_elvacenzy_2020.jpg
# Processed: augmented_rotate_elvacenzy_2020.jpg
# Processed: augmented_horizontal_elvacenzy_2015.jpg
# Processed: augmented_vertical_elvacenzy_2015.jpg
# Processed: augmented_rotate_elvacenzy_2015.jpg
# Processed: augmented_horizontal_elvacenzy_2010.jpg
# Processed: augmented_vertical_elvacenzy_2010.jpg
# Processed: augmented_horizontal_elvacenzy_2005.jpg
# Processed: augmented_rotate_elvacenzy_2010.jpg
# Processed: augmented_vertical_elvacenzy_2005.jpg
# Processed: augmented_rotate_elvacenzy_2005.jpg
# Processed: augmented_horizontal_elvacenzy_2000.jpg
# Processed: augmented_vertical_elvacenzy_2000.jpg
# Processed: augmented_horizontal_braf_2020.jpg
# Processed: augmented_rotate_elvacenzy_2000.jpg
# Processed: augmented_rotate_braf_2020.jpg
# Processed: augmented_vertical_braf_2020.jpg
# Processed: augmented_vertical_braf_2015.jpg
# Processed: augmented_horizontal_braf_2015.jpg
# Processed: augmented_rotate_braf_2015.jpg
# Processed: augmented_horizontal_braf_2010.jpg
# Processed: augmented_vertical_braf_2010.jpg
# Processed: augmented_rotate_braf_2010.jpg
# Processed: augmented_horizontal_braf_2005.jpg
# Processed: augmented_vertical_braf_2005.jpg
# Processed: augmented_rotate_braf_2005.jpg
# Processed: augmented_horizontal_braf_2000.jpg
# Processed: augmented_vertical_braf_2000.jpg
# Processed: augmented_rotate_braf_2000.jpg
# Processed: augmented_horizontal_dikato_2020.jpg
# Processed: augmented_vertical_dikato_2020.jpg
# Processed: augmented_rotate_dikato_2020.jpg
# Processed: augmented_horizontal_dikato_2015.jpg
# Processed: augmented_vertical_dikato_2015.jpg
# Processed: augmented_rotate_dikato_2015.jpg
# Processed: augmented_horizontal_dikato_2010.jpg
# Processed: augmented_vertical_dikato_2010.jpg
# Processed: augmented_rotate_dikato_2010.jpg
# Processed: augmented_horizontal_dikato_2005.jpg
# Processed: augmented_vertical_dikato_2005.jpg
# Processed: augmented_rotate_dikato_2005.jpg
# Processed: augmented_horizontal_dikato_2000.jpg
# Processed: augmented_vertical_dikato_2000.jpg
# Processed: augmented_rotate_dik_2020.jpg
# Processed: augmented_rotate_dikato_2000.jpg
# Processed: augmented_horizontal_dik_2020.jpg
# Processed: augmented_vertical_dik_2020.jpg
# Processed: augmented_horizontal_dik_2015.jpg
# Processed: augmented_vertical_dik_2015.jpg
# Processed: augmented_rotate_dik_2015.jpg
# Processed: augmented_horizontal_dik_2010.jpg
# Processed: augmented_vertical_dik_2010.jpg
# Processed: augmented_rotate_dik_2010.jpg
# Processed: augmented_horizontal_dik_2005.jpg
# Processed: augmented_vertical_dik_2005.jpg
# Processed: augmented_rotate_dik_2005.jpg
# Processed: augmented_horizontal_dik_2000.jpg
# Processed: augmented_vertical_dik_2000.jpg
# Processed: augmented_rotate_dik_2000.jpg
# Processed: augmented_horizontal_essa_2020.jpg
# Processed: augmented_vertical_essa_2020.jpg
# Processed: augmented_rotate_essa_2020.jpg
# Processed: augmented_horizontal_essa_2015.jpg
# Processed: augmented_vertical_essa_2015.jpg
# Processed: augmented_rotate_essa_2015.jpg
# Processed: augmented_horizontal_essa_2010.jpg
# Processed: augmented_vertical_essa_2010.jpg
# Processed: augmented_horizontal_essa_2005.jpg
# Processed: augmented_rotate_essa_2010.jpg
# Processed: augmented_vertical_essa_2005.jpg
# Processed: augmented_rotate_essa_2005.jpg
# Processed: augmented_horizontal_essa_2000.jpg
# Processed: augmented_vertical_essa_2000.jpg
# Processed: augmented_rotate_essa_2000.jpg
# Processed: augmented_horizontal_emma_2020.jpg
# Processed: augmented_vertical_emma_2020.jpg
# Processed: augmented_rotate_emma_2020.jpg
# Processed: augmented_vertical_emma_2015.jpg
# Processed: augmented_horizontal_emma_2015.jpg
# Processed: augmented_rotate_emma_2015.jpg
# Processed: augmented_horizontal_emma_2010.jpg
# Processed: augmented_vertical_emma_2010.jpg
# Processed: augmented_rotate_emma_2010.jpg
# Processed: augmented_horizontal_emma_2005.jpg
# Processed: augmented_rotate_emma_2005.jpg
# Processed: augmented_vertical_emma_2005.jpg
# Processed: augmented_horizontal_emma_2000.jpg
# Processed: augmented_horizontal_esa_2020.jpg
# Processed: augmented_vertical_esa_2020.jpg
# Processed: augmented_rotate_emma_2000.jpg
# Processed: augmented_rotate_esa_2020.jpg
# Processed: augmented_vertical_emma_2000.jpg
# Processed: augmented_horizontal_esa_2015.jpg
# Processed: augmented_vertical_esa_2015.jpg
# Processed: augmented_rotate_esa_2015.jpg
# Processed: augmented_horizontal_esa_2010.jpg
# Processed: augmented_vertical_esa_2010.jpg
# Processed: augmented_rotate_esa_2010.jpg
# Processed: augmented_horizontal_esa_2005.jpg
# Processed: augmented_vertical_esa_2005.jpg
# Processed: augmented_horizontal_esa_2000.jpg
# Processed: augmented_rotate_esa_2005.jpg
# Processed: augmented_vertical_esa_2000.jpg
# Processed: augmented_rotate_esa_2000.jpg
# Processed: augmented_horizontal_eta_2020.jpg
# Processed: augmented_vertical_eta_2020.jpg
# Processed: augmented_rotate_eta_2020.jpg
# Processed: augmented_horizontal_eta_2015.jpg
# Processed: augmented_horizontal_eta_2010.jpg
# Processed: augmented_vertical_eta_2015.jpg
# Processed: augmented_rotate_eta_2015.jpg
# Processed: augmented_vertical_eta_2010.jpg
# Processed: augmented_rotate_eta_2010.jpg
# Processed: augmented_horizontal_eta_2005.jpg
# Processed: augmented_vertical_eta_2005.jpg
# Processed: augmented_rotate_eta_2005.jpg
# Processed: augmented_vertical_eta_2000.jpg
# Processed: augmented_horizontal_eta_2000.jpg
# Processed: augmented_rotate_eta_2000.jpg
# Processed: augmented_horizontal_casas_2020.jpg
# Processed: augmented_vertical_casas_2020.jpg
# Processed: augmented_rotate_casas_2020.jpg
# Processed: augmented_vertical_casas_2015.jpg
# Processed: augmented_horizontal_casas_2015.jpg
# Processed: augmented_rotate_casas_2015.jpg
# Processed: augmented_vertical_casas_2010.jpg
# Processed: augmented_horizontal_casas_2010.jpg
# Processed: augmented_rotate_casas_2010.jpg
# Processed: augmented_horizontal_casas_2005.jpg
# Processed: augmented_vertical_casas_2005.jpg
# Processed: augmented_horizontal_casas_2000.jpg
# Processed: augmented_vertical_casas_2000.jpg
# Processed: augmented_rotate_casas_2000.jpg
# Processed: augmented_rotate_casas_2005.jpg
# Processed: augmented_horizontal_silva_2020.jpg
# Processed: augmented_vertical_silva_2020.jpg
# Processed: augmented_rotate_silva_2020.jpg
# Processed: augmented_horizontal_silva_2015.jpg
# Processed: augmented_vertical_silva_2015.jpg
# Processed: augmented_rotate_silva_2015.jpg
# Processed: augmented_horizontal_silva_2010.jpg
# Processed: augmented_vertical_silva_2010.jpg
# Processed: augmented_rotate_silva_2010.jpg
# Processed: augmented_horizontal_silva_2005.jpg
# Processed: augmented_vertical_silva_2005.jpg
# Processed: augmented_rotate_silva_2005.jpg
# Processed: augmented_horizontal_silva_2000.jpg
# Processed: augmented_vertical_silva_2000.jpg
# Processed: augmented_rotate_silva_2000.jpg
# Processed: augmented_horizontal_bata_2020.jpg
# Processed: augmented_rotate_bata_2020.jpg
# Processed: augmented_vertical_bata_2020.jpg
# Processed: augmented_horizontal_bata_2015.jpg
# Processed: augmented_vertical_bata_2015.jpg
# Processed: augmented_horizontal_bata_2010.jpg
# Processed: augmented_rotate_bata_2015.jpg
# Processed: augmented_rotate_bata_2010.jpg
# Processed: augmented_vertical_bata_2010.jpg
# Processed: augmented_horizontal_bata_2005.jpg
# Processed: augmented_rotate_bata_2005.jpg
# Processed: augmented_horizontal_bata_2000.jpg
# Processed: augmented_vertical_bata_2005.jpg
# Processed: augmented_rotate_bata_2000.jpg
# Processed: augmented_vertical_bata_2000.jpg
# Processed: augmented_vertical_b_2020.jpg
# Processed: augmented_rotate_b_2020.jpg
# Processed: augmented_horizontal_b_2020.jpg
# Processed: augmented_horizontal_b_2015.jpg
# Processed: augmented_vertical_b_2015.jpg
# Processed: augmented_rotate_b_2015.jpg
# Processed: augmented_vertical_b_2010.jpg
# Processed: augmented_horizontal_b_2010.jpg
# Processed: augmented_rotate_b_2010.jpg
# Processed: augmented_horizontal_b_2005.jpg
# Processed: augmented_rotate_b_2005.jpg
# Processed: augmented_vertical_b_2005.jpg
# Processed: augmented_horizontal_b_2000.jpg
# Processed: augmented_vertical_b_2000.jpg
# Processed: augmented_rotate_b_2000.jpg
# Processed: augmented_horizontal_s_2020.jpg
# Processed: augmented_vertical_s_2020.jpg
# Processed: augmented_rotate_s_2020.jpg
# Processed: augmented_horizontal_s_2015.jpg
# Processed: augmented_vertical_s_2015.jpg
# Processed: augmented_rotate_s_2015.jpg
# Processed: augmented_vertical_s_2010.jpg
# Processed: augmented_horizontal_s_2010.jpg
# Processed: augmented_rotate_s_2010.jpg
# Processed: augmented_horizontal_s_2005.jpg
# Processed: augmented_vertical_s_2005.jpg
# Processed: augmented_rotate_s_2005.jpg
# Processed: augmented_vertical_s_2000.jpg
# Processed: augmented_horizontal_s_2000.jpg
# Processed: augmented_rotate_s_2000.jpg
# Processed: augmented_horizontal_sa_2020.jpg
# Processed: augmented_vertical_sa_2020.jpg
# Processed: augmented_rotate_sa_2020.jpg
# Processed: augmented_horizontal_sa_2015.jpg
# Processed: augmented_vertical_sa_2015.jpg
# Processed: augmented_rotate_sa_2015.jpg
# Processed: augmented_horizontal_sa_2010.jpg
# Processed: augmented_vertical_sa_2010.jpg
# Processed: augmented_rotate_sa_2010.jpg
# Processed: augmented_horizontal_sa_2005.jpg
# Processed: augmented_vertical_sa_2005.jpg
# Processed: augmented_rotate_sa_2005.jpg
# Processed: augmented_horizontal_sa_2000.jpg
# Processed: augmented_vertical_sa_2000.jpg
# Processed: augmented_rotate_sa_2000.jpg
# Processing complete.
