# %%
from PIL import Image
import os

# Define input and output directories
input_dir = "/content/drive/MyDrive/Sowmik Dataset/New dataset/Residence"
output_dir = "/content/drive/MyDrive/Sowmik Dataset/New dataset/Residence_all_processed_data"

# Create the output directory if it doesn't exist
#if not os.path.exists(output_dir):
#    os.makedirs(output_dir)

# Define a function for image preprocessing
def preprocess_image(input_path, output_path, target_size=(256, 256)):
    try:
        # Open the image
        img = Image.open(input_path)

        # Resize the image to the target size
        img = img.resize(target_size, Image.ANTIALIAS)

        # Save the preprocessed image
        img.save(output_path)
        print(f"Processed: {input_path} -> {output_path}")
    except Exception as e:
        print(f"Error processing {input_path}: {str(e)}")

# Process all images in the input directory
for filename in os.listdir(input_dir):
    if filename.endswith((".jpg", ".jpeg", ".png")):
        input_path = os.path.join(input_dir, filename)
        output_path = os.path.join(output_dir, filename)
        preprocess_image(input_path, output_path)

print("Image preprocessing complete.")
# Out:
# <ipython-input-4-76efb7b072ea>:19: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   img = img.resize(target_size, Image.ANTIALIAS)
# Processed: /content/drive/MyDrive/Sowmik Dataset/New dataset/Residence/lara_2010.jpg -> /content/drive/MyDrive/Sowmik Dataset/New dataset/Residence_all_processed_data/lara_2010.jpg
# Processed: /content/drive/MyDrive/Sowmik Dataset/New dataset/Residence/lara_2005.jpg -> /content/drive/MyDrive/Sowmik Dataset/New dataset/Residence_all_processed_data/lara_2005.jpg
# Processed: /content/drive/MyDrive/Sowmik Dataset/New dataset/Residence/lara_2000.jpg -> /content/drive/MyDrive/Sowmik Dataset/New dataset/Residence_all_processed_data/lara_2000.jpg
# Processed: /content/drive/MyDrive/Sowmik Dataset/New dataset/Residence/escola_2020.jpg -> /content/drive/MyDrive/Sowmik Dataset/New dataset/Residence_all_processed_data/escola_2020.jpg
# ...
